# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/kddcup99_csv.csv')

# %%
#dimensions of the dataset
data.shape
# Out:
# (494020, 42)

# %%
#datatypes of each columns
data.dtypes
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# lnum_compromised                 int64
# lroot_shell                      int64
# lsu_attempted                    int64
# lnum_root                        int64
# lnum_file_creations              int64
# lnum_shells                      int64
# lnum_access_files                int64
# lnum_outbound_cmds               int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# ...

# %%
#first 5 rows details
data.head()
# Out:
#    duration protocol_type  ... dst_host_srv_rerror_rate   label
# 0         0           tcp  ...                      0.0  normal
# 1         0           tcp  ...                      0.0  normal
# 2         0           tcp  ...                      0.0  normal
# 3         0           tcp  ...                      0.0  normal
# 4         0           tcp  ...                      0.0  normal
#
# [5 rows x 42 columns]

# %%
#last 5 rows details
data.tail()
# Out:
#         duration protocol_type  ... dst_host_srv_rerror_rate   label
# 494015         0           tcp  ...                      0.0  normal
# 494016         0           tcp  ...                      0.0  normal
# 494017         0           tcp  ...                      0.0  normal
# 494018         0           tcp  ...                      0.0  normal
# 494019         0           tcp  ...                      0.0  normal
#
# [5 rows x 42 columns]

# %%
#checking the column names
data.columns.values
# Out:
# array(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'lnum_compromised',
#        'lroot_shell', 'lsu_attempted', 'lnum_root', 'lnum_file_creations',
#        'lnum_shells', 'lnum_access_files', 'lnum_outbound_cmds',
#        'is_host_login', 'is_guest_login', 'count', 'srv_count',
#        'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
#        'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
#        'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'label'], dtype=object)

# %%
#checking the different types of protocol_type data
numProtocol_types=data.protocol_type.value_counts(ascending = True)
number = pd.Series(numProtocol_types)
number
# Out:
# udp      20354
# tcp     190064
# icmp    283602
# Name: protocol_type, dtype: int64

# %%
#checking the different attack types available in the dataset
Attack_types = data.label.value_counts(ascending = True)
num = pd.Series(Attack_types)
num
# Out:
# spy                     2
# perl                    3
# phf                     4
# multihop                7
# ftp_write               8
# loadmodule              9
# rootkit                10
# imap                   12
# warezmaster            20
# land                   21
# buffer_overflow        30
# guess_passwd           53
# nmap                  231
# pod                   264
# teardrop              979
# warezclient          1020
# portsweep            1040
# ipsweep              1247
# satan                1589
# back                 2203
# normal              97277
# neptune            107201
# smurf              280790
# Name: label, dtype: int64

# %%
#checking if there are any Null values in the dataset
data.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# lnum_compromised               0
# lroot_shell                    0
# lsu_attempted                  0
# lnum_root                      0
# lnum_file_creations            0
# lnum_shells                    0
# lnum_access_files              0
# lnum_outbound_cmds             0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
#extracting the icmp data from the dataset
icmp = data[data.loc[:,"protocol_type"]=="icmp"]

# %%
icmp.head()
# Out:
#      duration protocol_type  ... dst_host_srv_rerror_rate   label
# 818         0          icmp  ...                      0.0  normal
# 819         0          icmp  ...                      0.0  normal
# 820         0          icmp  ...                      0.0  normal
# 821         0          icmp  ...                      0.0  normal
# 833         0          icmp  ...                      0.0  normal
#
# [5 rows x 42 columns]

# %%
#extracting the udp data from the dataset
udp = data[data.loc[:,"protocol_type"]=="udp"]

# %%
udp.head()
# Out:
#      duration protocol_type  ... dst_host_srv_rerror_rate   label
# 213         0           udp  ...                      0.0  normal
# 214         0           udp  ...                      0.0  normal
# 217         0           udp  ...                      0.0  normal
# 219         0           udp  ...                      0.0  normal
# 224         0           udp  ...                      0.0  normal
#
# [5 rows x 42 columns]

# %%
#extracting the tcp data from the dataset
tcp = data[data.loc[:,"protocol_type"]=="tcp"]

# %%
tcp.head()
# Out:
#    duration protocol_type  ... dst_host_srv_rerror_rate   label
# 0         0           tcp  ...                      0.0  normal
# 1         0           tcp  ...                      0.0  normal
# 2         0           tcp  ...                      0.0  normal
# 3         0           tcp  ...                      0.0  normal
# 4         0           tcp  ...                      0.0  normal
#
# [5 rows x 42 columns]

# %%
#extracting all important features for preprocessing
features = ["duration","src_bytes","wrong_fragment","count","urgent","lnum_compromised","srv_count"]
target = "label"

# %%
X = icmp.loc[:,features]
y = icmp.loc[:,target]
